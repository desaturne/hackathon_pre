# %%
# !pip install ultralytics
# Out:
# Requirement already satisfied: ultralytics in /usr/local/lib/python3.11/dist-packages (8.3.159)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.11.0.86)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (11.2.1)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (1.15.3)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.6.0+cu124)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.21.0+cu124)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.0.14)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2025.6.15)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (4.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.11/dist-packages (from opencv-python) (2.0.2)

# %%
import cv2
from ultralytics import YOLO

# Load YOLOv8 model
model = YOLO("yolov8n.pt")

# Open video file
video_path = "test.mp4"
cap = cv2.VideoCapture(video_path)

# Optional: Prepare output video writer
out = cv2.VideoWriter("output.avi",
                      cv2.VideoWriter_fourcc(*'XVID'),
                      30.0,
                      (int(cap.get(3)), int(cap.get(4))))

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Run YOLOv8 on the current frame
    results = model(frame)

    # Draw results on frame
    annotated_frame = results[0].plot()

    out.write(annotated_frame)

    # Press 'q' to exit early
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
out.release()

# %%
import cv2
from ultralytics import YOLO

# Load YOLOv8 model (trained on COCO)
model = YOLO("yolov8n.pt")

# Open video file
video_path = "test.mp4"
cap = cv2.VideoCapture(video_path)

# Optional: Prepare output video writer
out = cv2.VideoWriter("output.avi",
                      cv2.VideoWriter_fourcc(*'XVID'),
                      30.0,
                      (int(cap.get(3)), int(cap.get(4))))

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Run YOLOv8 on the current frame
    results = model(frame)[0]  # get first result (frame-level)

    # Filter for class ID 32 -> "sports ball" in COCO
    ball_boxes = results.boxes
    if ball_boxes is not None:
        for box, cls in zip(ball_boxes.xyxy, ball_boxes.cls):
            if int(cls) == 32:
                x1, y1, x2, y2 = map(int, box[:4])
                cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 255), 2)
                cv2.putText(frame, "BALL", (x1, y1 - 10),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 255), 2)

    # Write annotated frame
    out.write(frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
out.release()

# %%
import cv2
from ultralytics import YOLO
from math import hypot
import pytesseract

# Load model
model = YOLO("yolov8n.pt")

# Open video
video_path = "test.mp4"
cap = cv2.VideoCapture(video_path)

# Output video writer
out = cv2.VideoWriter("output.avi",
                      cv2.VideoWriter_fourcc(*'XVID'),
                      30.0,
                      (int(cap.get(3)), int(cap.get(4))))

# Functions
def iou(boxA, boxB):
    xA = max(boxA[0], boxB[0])
    yA = max(boxA[1], boxB[1])
    xB = min(boxA[2], boxB[2])
    yB = min(boxA[3], boxB[3])
    interArea = max(0, xB - xA) * max(0, yB - yA)
    boxAArea = (boxA[2] - boxA[0]) * (boxA[3] - boxA[1])
    boxBArea = (boxB[2] - boxB[0]) * (boxB[3] - boxB[1])
    return interArea / float(boxAArea + boxBArea - interArea + 1e-5)

def center(box):
    x1, y1, x2, y2 = box
    return ((x1 + x2) // 2, (y1 + y2) // 2)

def is_touch(player_box, ball_box, threshold=40):
    px, py = center(player_box)
    bx, by = center(ball_box)
    return hypot(px - bx, py - by) < threshold

def extract_jersey_number(frame, box):
    x1, y1, x2, y2 = box
    jersey_crop = frame[y1:y2, x1:x2]
    jersey_crop = cv2.resize(jersey_crop, (100, 150))  # Normalize size
    gray = cv2.cvtColor(jersey_crop, cv2.COLOR_BGR2GRAY)
    text = pytesseract.image_to_string(gray, config='--psm 6 digits')
    return ''.join(filter(str.isdigit, text.strip()))

# Tracking variables
target_player_box = None
touches = 0
last_touched = False
salah_detected = False

frame_idx = 0
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    results = model(frame)[0]
    current_players = []
    current_ball = None

    # Extract boxes
    for box, cls in zip(results.boxes.xyxy, results.boxes.cls):
        x1, y1, x2, y2 = map(int, box[:4])
        if int(cls) == 0:  # person
            current_players.append((x1, y1, x2, y2))
        elif int(cls) == 32:  # ball
            current_ball = (x1, y1, x2, y2)

    # First few frames: identify Salah by jersey number 11
    if not salah_detected and frame_idx < 50:
        for player_box in current_players:
            number = extract_jersey_number(frame, player_box)
            if number == "11":
                print("Salah detected with jersey #11!")
                target_player_box = player_box
                salah_detected = True
                break

    # Track Salah by IoU
    if salah_detected and target_player_box:
        best_iou = 0
        best_match = None
        for player in current_players:
            iou_val = iou(target_player_box, player)
            if iou_val > best_iou:
                best_iou = iou_val
                best_match = player
        if best_match:
            target_player_box = best_match
            cv2.rectangle(frame, (target_player_box[0], target_player_box[1]),
                          (target_player_box[2], target_player_box[3]), (0, 255, 0), 2)
            cv2.putText(frame, "Salah", (target_player_box[0], target_player_box[1] - 10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)

    # Draw ball
    if current_ball:
        cv2.rectangle(frame, (current_ball[0], current_ball[1]),
                      (current_ball[2], current_ball[3]), (0, 255, 255), 2)
        cv2.putText(frame, "Ball", (current_ball[0], current_ball[1] - 10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 255), 2)

    # Detect touch
    if target_player_box and current_ball:
        if is_touch(target_player_box, current_ball):
            if not last_touched:
                touches += 1
                print(f"Touch #{touches}")
            last_touched = True
        else:
            last_touched = False

    # Draw touch count
    cv2.putText(frame, f"Salah Touches: {touches}", (10, 30),
                cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 255), 2)

    out.write(frame)

    frame_idx += 1
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# Streaming output truncated to the last 5000 lines.
# 0: 384x640 6 persons, 1 sports ball, 148.5ms
# Speed: 3.1ms preprocess, 148.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 2 sports balls, 147.9ms
# Speed: 3.1ms preprocess, 147.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 sports ball, 151.6ms
# Speed: 4.7ms preprocess, 151.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 sports ball, 159.0ms
# Speed: 3.3ms preprocess, 159.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 sports ball, 145.8ms
# Speed: 3.4ms preprocess, 145.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 sports ball, 149.6ms
# Speed: 3.5ms preprocess, 149.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 sports ball, 144.0ms
# Speed: 3.6ms preprocess, 144.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 2 sports balls, 170.0ms
# Speed: 3.2ms preprocess, 170.0ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 sports ball, 153.9ms
# Speed: 3.3ms preprocess, 153.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 2 sports balls, 144.4ms
# Speed: 4.8ms preprocess, 144.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 2 sports balls, 146.2ms
# Speed: 3.5ms preprocess, 146.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 sports ball, 150.2ms
# Speed: 3.2ms preprocess, 150.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 sports ball, 147.2ms
# Speed: 3.8ms preprocess, 147.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 2 sports balls, 156.1ms
# Speed: 4.1ms preprocess, 156.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 2 sports balls, 152.0ms
# Speed: 4.7ms preprocess, 152.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 2 sports balls, 150.7ms
# Speed: 3.4ms preprocess, 150.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 sports ball, 220.9ms
# Speed: 3.2ms preprocess, 220.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 2 sports balls, 239.0ms
# Speed: 3.5ms preprocess, 239.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 2 sports balls, 242.8ms
# Speed: 3.1ms preprocess, 242.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 sports ball, 227.6ms
# Speed: 3.7ms preprocess, 227.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 sports ball, 228.1ms
# Speed: 5.4ms preprocess, 228.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 sports ball, 223.6ms
# Speed: 3.2ms preprocess, 223.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 sports ball, 235.0ms
# Speed: 3.3ms preprocess, 235.0ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 2 sports balls, 237.1ms
# Speed: 3.4ms preprocess, 237.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 2 sports balls, 232.4ms
# Speed: 3.3ms preprocess, 232.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 sports ball, 238.5ms
# Speed: 3.8ms preprocess, 238.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 sports ball, 196.7ms
# Speed: 3.3ms preprocess, 196.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 sports ball, 164.6ms
# Speed: 3.4ms preprocess, 164.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 sports ball, 150.3ms
# Speed: 3.3ms preprocess, 150.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 sports ball, 144.5ms
# Speed: 4.6ms preprocess, 144.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 sports ball, 150.7ms
# Speed: 3.4ms preprocess, 150.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 sports ball, 148.9ms
# Speed: 2.8ms preprocess, 148.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 sports ball, 150.2ms
# Speed: 3.4ms preprocess, 150.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 sports ball, 161.4ms
# Speed: 3.2ms preprocess, 161.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 sports ball, 148.6ms
# Speed: 3.4ms preprocess, 148.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 sports ball, 154.1ms
# Speed: 4.4ms preprocess, 154.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 sports ball, 145.9ms
# Speed: 3.3ms preprocess, 145.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 bird, 1 sports ball, 152.0ms
# Speed: 3.2ms preprocess, 152.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 sports ball, 149.7ms
# Speed: 3.7ms preprocess, 149.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 sports ball, 159.3ms
# Speed: 3.7ms preprocess, 159.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 sports ball, 148.2ms
# Speed: 3.3ms preprocess, 148.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 sports ball, 151.9ms
# Speed: 3.4ms preprocess, 151.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 sports ball, 152.1ms
# Speed: 3.1ms preprocess, 152.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 sports ball, 150.7ms
# Speed: 3.2ms preprocess, 150.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 sports ball, 150.4ms
# Speed: 3.4ms preprocess, 150.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bird, 1 sports ball, 157.8ms
# Speed: 3.5ms preprocess, 157.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 bird, 2 sports balls, 146.8ms
# Speed: 3.6ms preprocess, 146.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 sports ball, 147.6ms
# Speed: 3.3ms preprocess, 147.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 sports ball, 149.9ms
# Speed: 3.5ms preprocess, 149.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 2 sports balls, 147.4ms
# Speed: 3.2ms preprocess, 147.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 2 sports balls, 148.1ms
# Speed: 3.3ms preprocess, 148.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 2 sports balls, 163.9ms
# Speed: 3.4ms preprocess, 163.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 2 sports balls, 150.2ms
# Speed: 3.4ms preprocess, 150.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 sports ball, 146.8ms
# Speed: 3.3ms preprocess, 146.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 sports ball, 153.3ms
# Speed: 3.2ms preprocess, 153.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 sports ball, 149.3ms
# Speed: 3.4ms preprocess, 149.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 146.8ms
# Speed: 3.4ms preprocess, 146.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 158.9ms
# Speed: 3.4ms preprocess, 158.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 sports ball, 150.4ms
# Speed: 3.0ms preprocess, 150.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 sports ball, 149.1ms
# Speed: 3.2ms preprocess, 149.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 sports ball, 148.7ms
# Speed: 3.4ms preprocess, 148.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 153.0ms
# Speed: 3.2ms preprocess, 153.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 153.8ms
# Speed: 3.5ms preprocess, 153.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 156.3ms
# Speed: 3.2ms preprocess, 156.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 sports ball, 151.8ms
# Speed: 3.1ms preprocess, 151.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 149.6ms
# Speed: 3.3ms preprocess, 149.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 146.5ms
# Speed: 4.7ms preprocess, 146.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 sports ball, 148.4ms
# Speed: 3.2ms preprocess, 148.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 sports ball, 151.6ms
# Speed: 3.1ms preprocess, 151.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 2 sports balls, 161.1ms
# Speed: 3.2ms preprocess, 161.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 2 sports balls, 173.6ms
# Speed: 3.5ms preprocess, 173.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 sports ball, 148.5ms
# Speed: 3.5ms preprocess, 148.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 sports ball, 146.7ms
# Speed: 3.3ms preprocess, 146.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 2 sports balls, 144.2ms
# Speed: 3.1ms preprocess, 144.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 2 sports balls, 162.8ms
# Speed: 3.1ms preprocess, 162.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 sports ball, 145.9ms
# Speed: 4.4ms preprocess, 145.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 147.8ms
# Speed: 3.2ms preprocess, 147.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 2 sports balls, 152.7ms
# Speed: 3.4ms preprocess, 152.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 2 sports balls, 146.8ms
# Speed: 3.1ms preprocess, 146.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 148.4ms
# Speed: 5.6ms preprocess, 148.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 sports ball, 164.9ms
# Speed: 3.1ms preprocess, 164.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 sports ball, 151.7ms
# Speed: 3.0ms preprocess, 151.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 154.1ms
# Speed: 3.0ms preprocess, 154.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 205.9ms
# Speed: 3.9ms preprocess, 205.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 242.8ms
# Speed: 3.3ms preprocess, 242.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 238.3ms
# Speed: 3.4ms preprocess, 238.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 234.9ms
# Speed: 3.2ms preprocess, 234.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 sports ball, 234.3ms
# Speed: 3.7ms preprocess, 234.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 sports ball, 221.5ms
# Speed: 3.5ms preprocess, 221.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 sports ball, 226.4ms
# Speed: 3.9ms preprocess, 226.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 sports ball, 227.4ms
# Speed: 3.2ms preprocess, 227.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 sports ball, 225.5ms
# Speed: 6.2ms preprocess, 225.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 sports ball, 241.6ms
# Speed: 4.2ms preprocess, 241.6ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 2 sports balls, 239.8ms
# Speed: 6.4ms preprocess, 239.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 sports ball, 155.3ms
# Speed: 4.1ms preprocess, 155.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 sports ball, 154.3ms
# Speed: 3.7ms preprocess, 154.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 sports ball, 151.0ms
# Speed: 3.3ms preprocess, 151.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 sports ball, 150.1ms
# Speed: 3.0ms preprocess, 150.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 3 sports balls, 149.1ms
# Speed: 3.2ms preprocess, 149.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 sports ball, 161.2ms
# Speed: 3.4ms preprocess, 161.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 2 sports balls, 154.3ms
# Speed: 3.7ms preprocess, 154.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 sports ball, 160.6ms
# Speed: 3.2ms preprocess, 160.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 sports ball, 151.2ms
# Speed: 3.2ms preprocess, 151.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 2 sports balls, 148.7ms
# Speed: 6.4ms preprocess, 148.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 sports ball, 147.0ms
# Speed: 3.3ms preprocess, 147.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 sports ball, 173.0ms
# Speed: 3.5ms preprocess, 173.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 2 sports balls, 147.6ms
# Speed: 3.3ms preprocess, 147.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 sports ball, 143.0ms
# Speed: 3.4ms preprocess, 143.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 sports ball, 154.5ms
# Speed: 3.0ms preprocess, 154.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 2 sports balls, 146.2ms
# Speed: 3.1ms preprocess, 146.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 sports ball, 150.2ms
# Speed: 3.3ms preprocess, 150.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 2 sports balls, 162.4ms
# Speed: 3.2ms preprocess, 162.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 sports ball, 148.1ms
# Speed: 3.4ms preprocess, 148.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 sports ball, 143.7ms
# Speed: 3.2ms preprocess, 143.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 sports ball, 155.6ms
# Speed: 3.3ms preprocess, 155.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 sports ball, 154.5ms
# Speed: 3.1ms preprocess, 154.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 2 sports balls, 147.2ms
# Speed: 3.4ms preprocess, 147.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 2 sports balls, 158.5ms
# Speed: 3.1ms preprocess, 158.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 sports ball, 144.4ms
# Speed: 3.0ms preprocess, 144.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 sports ball, 143.6ms
# Speed: 3.1ms preprocess, 143.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 sports ball, 152.8ms
# Speed: 3.7ms preprocess, 152.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 sports ball, 149.8ms
# Speed: 3.5ms preprocess, 149.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 sports ball, 157.8ms
# Speed: 3.0ms preprocess, 157.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 2 sports balls, 166.1ms
# Speed: 4.1ms preprocess, 166.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 sports ball, 147.9ms
# Speed: 3.2ms preprocess, 147.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 2 sports balls, 149.6ms
# Speed: 2.9ms preprocess, 149.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 2 sports balls, 147.1ms
# Speed: 3.3ms preprocess, 147.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 2 sports balls, 153.1ms
# Speed: 3.1ms preprocess, 153.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 sports ball, 151.1ms
# Speed: 3.2ms preprocess, 151.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 sports ball, 167.0ms
# Speed: 3.5ms preprocess, 167.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 sports ball, 151.1ms
# Speed: 3.4ms preprocess, 151.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 148.1ms
# Speed: 3.5ms preprocess, 148.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 151.2ms
# Speed: 3.4ms preprocess, 151.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 147.2ms
# Speed: 3.2ms preprocess, 147.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 149.2ms
# Speed: 3.3ms preprocess, 149.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 168.6ms
# Speed: 3.4ms preprocess, 168.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 144.0ms
# Speed: 3.3ms preprocess, 144.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 151.5ms
# Speed: 3.4ms preprocess, 151.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 145.3ms
# Speed: 3.2ms preprocess, 145.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 153.9ms
# Speed: 3.2ms preprocess, 153.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 sports ball, 147.9ms
# Speed: 6.9ms preprocess, 147.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 2 sports balls, 167.4ms
# Speed: 3.4ms preprocess, 167.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 2 sports balls, 149.7ms
# Speed: 3.6ms preprocess, 149.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 sports ball, 144.2ms
# Speed: 3.3ms preprocess, 144.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 sports ball, 150.5ms
# Speed: 3.3ms preprocess, 150.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 152.5ms
# Speed: 3.4ms preprocess, 152.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 149.7ms
# Speed: 3.0ms preprocess, 149.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 154.5ms
# Speed: 3.3ms preprocess, 154.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 148.2ms
# Speed: 4.8ms preprocess, 148.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 146.5ms
# Speed: 3.3ms preprocess, 146.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 164.8ms
# Speed: 3.3ms preprocess, 164.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 229.8ms
# Speed: 3.4ms preprocess, 229.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 243.6ms
# Speed: 3.1ms preprocess, 243.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 225.6ms
# Speed: 5.3ms preprocess, 225.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 220.9ms
# Speed: 3.1ms preprocess, 220.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 232.1ms
# Speed: 3.4ms preprocess, 232.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 257.4ms
# Speed: 3.2ms preprocess, 257.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 221.4ms
# Speed: 6.5ms preprocess, 221.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 230.8ms
# Speed: 3.9ms preprocess, 230.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 241.8ms
# Speed: 3.5ms preprocess, 241.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 242.6ms
# Speed: 3.3ms preprocess, 242.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 197.1ms
# Speed: 3.5ms preprocess, 197.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 146.9ms
# Speed: 3.1ms preprocess, 146.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 149.9ms
# Speed: 3.4ms preprocess, 149.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 152.8ms
# Speed: 3.0ms preprocess, 152.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 144.1ms
# Speed: 3.1ms preprocess, 144.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 163.2ms
# Speed: 3.1ms preprocess, 163.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 142.4ms
# Speed: 3.7ms preprocess, 142.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 145.9ms
# Speed: 3.3ms preprocess, 145.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 144.8ms
# Speed: 3.1ms preprocess, 144.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 146.6ms
# Speed: 3.2ms preprocess, 146.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 148.8ms
# Speed: 3.3ms preprocess, 148.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 161.8ms
# Speed: 3.8ms preprocess, 161.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 147.3ms
# Speed: 3.1ms preprocess, 147.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 151.9ms
# Speed: 3.4ms preprocess, 151.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 148.1ms
# Speed: 3.2ms preprocess, 148.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 144.7ms
# Speed: 3.3ms preprocess, 144.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 149.3ms
# Speed: 3.3ms preprocess, 149.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 161.5ms
# Speed: 3.5ms preprocess, 161.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 sports ball, 145.5ms
# Speed: 3.4ms preprocess, 145.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 sports ball, 151.3ms
# Speed: 3.4ms preprocess, 151.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 145.9ms
# Speed: 3.5ms preprocess, 145.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 146.4ms
# Speed: 3.0ms preprocess, 146.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 149.9ms
# Speed: 3.6ms preprocess, 149.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 169.2ms
# Speed: 3.4ms preprocess, 169.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 149.1ms
# Speed: 3.2ms preprocess, 149.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 148.3ms
# Speed: 4.5ms preprocess, 148.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 149.6ms
# Speed: 6.8ms preprocess, 149.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 148.5ms
# Speed: 3.3ms preprocess, 148.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 150.0ms
# Speed: 3.2ms preprocess, 150.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 151.2ms
# Speed: 6.7ms preprocess, 151.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 149.3ms
# Speed: 6.9ms preprocess, 149.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 149.9ms
# Speed: 3.2ms preprocess, 149.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 151.6ms
# Speed: 3.5ms preprocess, 151.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 148.6ms
# Speed: 3.6ms preprocess, 148.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 155.7ms
# Speed: 3.4ms preprocess, 155.7ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 144.6ms
# Speed: 4.9ms preprocess, 144.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 149.5ms
# Speed: 3.2ms preprocess, 149.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 148.9ms
# Speed: 3.5ms preprocess, 148.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 147.7ms
# Speed: 3.5ms preprocess, 147.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 146.9ms
# Speed: 3.1ms preprocess, 146.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 162.6ms
# Speed: 3.6ms preprocess, 162.6ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 146.0ms
# Speed: 3.2ms preprocess, 146.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 150.8ms
# Speed: 3.5ms preprocess, 150.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 148.0ms
# Speed: 3.2ms preprocess, 148.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 145.5ms
# Speed: 3.1ms preprocess, 145.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 144.0ms
# Speed: 3.5ms preprocess, 144.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 150.5ms
# Speed: 3.2ms preprocess, 150.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 158.5ms
# Speed: 3.5ms preprocess, 158.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 147.5ms
# Speed: 3.6ms preprocess, 147.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 146.4ms
# Speed: 3.7ms preprocess, 146.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 145.2ms
# Speed: 3.2ms preprocess, 145.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 145.9ms
# Speed: 3.4ms preprocess, 145.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 144.2ms
# Speed: 3.1ms preprocess, 144.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 160.0ms
# Speed: 6.2ms preprocess, 160.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 147.6ms
# Speed: 3.3ms preprocess, 147.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 154.7ms
# Speed: 3.3ms preprocess, 154.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 150.8ms
# Speed: 3.2ms preprocess, 150.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 178.7ms
# Speed: 3.4ms preprocess, 178.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 238.5ms
# Speed: 3.1ms preprocess, 238.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 233.2ms
# Speed: 3.3ms preprocess, 233.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 220.5ms
# Speed: 3.3ms preprocess, 220.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 232.8ms
# Speed: 3.2ms preprocess, 232.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 252.2ms
# Speed: 3.3ms preprocess, 252.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 222.5ms
# Speed: 6.3ms preprocess, 222.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 233.3ms
# Speed: 3.3ms preprocess, 233.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 256.9ms
# Speed: 3.6ms preprocess, 256.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 240.5ms
# Speed: 3.3ms preprocess, 240.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 196.4ms
# Speed: 4.9ms preprocess, 196.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 143.0ms
# Speed: 4.1ms preprocess, 143.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 150.0ms
# Speed: 3.3ms preprocess, 150.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 146.6ms
# Speed: 3.6ms preprocess, 146.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 1 sports ball, 153.3ms
# Speed: 3.3ms preprocess, 153.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 149.0ms
# Speed: 3.4ms preprocess, 149.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 140.4ms
# Speed: 3.3ms preprocess, 140.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 144.6ms
# Speed: 3.2ms preprocess, 144.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 147.8ms
# Speed: 3.3ms preprocess, 147.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 152.1ms
# Speed: 3.4ms preprocess, 152.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 154.3ms
# Speed: 3.0ms preprocess, 154.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 149.5ms
# Speed: 3.2ms preprocess, 149.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 151.0ms
# Speed: 3.4ms preprocess, 151.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 146.8ms
# Speed: 3.3ms preprocess, 146.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 147.8ms
# Speed: 3.3ms preprocess, 147.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 149.6ms
# Speed: 3.5ms preprocess, 149.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 161.7ms
# Speed: 5.7ms preprocess, 161.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 146.7ms
# Speed: 3.3ms preprocess, 146.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 152.8ms
# Speed: 3.3ms preprocess, 152.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 155.8ms
# Speed: 3.6ms preprocess, 155.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 151.4ms
# Speed: 3.3ms preprocess, 151.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 148.4ms
# Speed: 3.2ms preprocess, 148.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 166.8ms
# Speed: 4.7ms preprocess, 166.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 151.3ms
# Speed: 3.4ms preprocess, 151.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 146.9ms
# Speed: 7.8ms preprocess, 146.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 151.6ms
# Speed: 3.3ms preprocess, 151.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 147.8ms
# Speed: 4.5ms preprocess, 147.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 150.5ms
# Speed: 3.5ms preprocess, 150.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 159.6ms
# Speed: 3.1ms preprocess, 159.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 1 sports ball, 144.1ms
# Speed: 3.6ms preprocess, 144.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 1 sports ball, 145.8ms
# Speed: 3.5ms preprocess, 145.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 1 sports ball, 145.3ms
# Speed: 3.1ms preprocess, 145.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 1 sports ball, 148.5ms
# Speed: 3.0ms preprocess, 148.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 1 sports ball, 150.1ms
# Speed: 3.1ms preprocess, 150.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 2 sports balls, 160.7ms
# Speed: 3.3ms preprocess, 160.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 1 sports ball, 145.0ms
# Speed: 3.5ms preprocess, 145.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 1 sports ball, 150.2ms
# Speed: 3.1ms preprocess, 150.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 2 sports balls, 149.3ms
# Speed: 3.1ms preprocess, 149.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 1 sports ball, 144.7ms
# Speed: 5.8ms preprocess, 144.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 1 sports ball, 145.2ms
# Speed: 3.1ms preprocess, 145.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 1 sports ball, 160.4ms
# Speed: 3.1ms preprocess, 160.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 1 sports ball, 141.7ms
# Speed: 3.1ms preprocess, 141.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 1 sports ball, 149.7ms
# Speed: 4.3ms preprocess, 149.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 1 sports ball, 148.2ms
# Speed: 3.0ms preprocess, 148.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 147.9ms
# Speed: 3.3ms preprocess, 147.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 1 sports ball, 144.3ms
# Speed: 4.4ms preprocess, 144.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 1 sports ball, 162.3ms
# Speed: 3.1ms preprocess, 162.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 1 sports ball, 146.2ms
# Speed: 3.0ms preprocess, 146.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 1 sports ball, 150.1ms
# Speed: 3.2ms preprocess, 150.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 1 sports ball, 152.6ms
# Speed: 3.1ms preprocess, 152.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 1 sports ball, 149.1ms
# Speed: 3.4ms preprocess, 149.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 1 sports ball, 146.0ms
# Speed: 3.4ms preprocess, 146.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 1 sports ball, 160.6ms
# Speed: 4.6ms preprocess, 160.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 1 sports ball, 156.4ms
# Speed: 3.0ms preprocess, 156.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 1 sports ball, 151.4ms
# Speed: 3.2ms preprocess, 151.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 2 sports balls, 148.8ms
# Speed: 3.3ms preprocess, 148.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 2 sports balls, 152.4ms
# Speed: 3.2ms preprocess, 152.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 1 sports ball, 203.8ms
# Speed: 6.0ms preprocess, 203.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 1 sports ball, 234.8ms
# Speed: 3.3ms preprocess, 234.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 1 sports ball, 234.1ms
# Speed: 6.2ms preprocess, 234.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 1 sports ball, 227.1ms
# Speed: 6.5ms preprocess, 227.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 1 sports ball, 235.1ms
# Speed: 3.3ms preprocess, 235.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 1 sports ball, 239.2ms
# Speed: 5.8ms preprocess, 239.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 1 sports ball, 222.0ms
# Speed: 3.5ms preprocess, 222.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 1 sports ball, 244.7ms
# Speed: 3.2ms preprocess, 244.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 253.9ms
# Speed: 5.5ms preprocess, 253.9ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 231.2ms
# Speed: 3.1ms preprocess, 231.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 213.6ms
# Speed: 3.4ms preprocess, 213.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 1 sports ball, 148.9ms
# Speed: 3.7ms preprocess, 148.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 147.1ms
# Speed: 3.1ms preprocess, 147.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 148.0ms
# Speed: 3.5ms preprocess, 148.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 159.0ms
# Speed: 3.9ms preprocess, 159.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 144.8ms
# Speed: 4.6ms preprocess, 144.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 152.6ms
# Speed: 3.1ms preprocess, 152.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 146.0ms
# Speed: 3.6ms preprocess, 146.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 148.3ms
# Speed: 3.3ms preprocess, 148.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 144.1ms
# Speed: 3.3ms preprocess, 144.1ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 170.2ms
# Speed: 3.4ms preprocess, 170.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 146.7ms
# Speed: 3.2ms preprocess, 146.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 146.1ms
# Speed: 3.5ms preprocess, 146.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 147.5ms
# Speed: 3.6ms preprocess, 147.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 145.9ms
# Speed: 3.1ms preprocess, 145.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 145.2ms
# Speed: 3.2ms preprocess, 145.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 163.4ms
# Speed: 3.0ms preprocess, 163.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 155.6ms
# Speed: 3.3ms preprocess, 155.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 148.2ms
# Speed: 3.2ms preprocess, 148.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 146.7ms
# Speed: 3.3ms preprocess, 146.7ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 146.5ms
# Speed: 3.0ms preprocess, 146.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 148.3ms
# Speed: 3.1ms preprocess, 148.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 165.6ms
# Speed: 4.6ms preprocess, 165.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 146.2ms
# Speed: 7.5ms preprocess, 146.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 148.6ms
# Speed: 3.2ms preprocess, 148.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 142.0ms
# Speed: 4.2ms preprocess, 142.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 147.7ms
# Speed: 3.1ms preprocess, 147.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 155.2ms
# Speed: 3.1ms preprocess, 155.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 161.1ms
# Speed: 3.4ms preprocess, 161.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 147.2ms
# Speed: 3.1ms preprocess, 147.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 154.9ms
# Speed: 3.5ms preprocess, 154.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 146.4ms
# Speed: 3.3ms preprocess, 146.4ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 144.1ms
# Speed: 3.4ms preprocess, 144.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 146.9ms
# Speed: 4.8ms preprocess, 146.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 161.9ms
# Speed: 3.4ms preprocess, 161.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 146.8ms
# Speed: 4.2ms preprocess, 146.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 155.2ms
# Speed: 3.5ms preprocess, 155.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 151.7ms
# Speed: 4.1ms preprocess, 151.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 158.8ms
# Speed: 3.4ms preprocess, 158.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 157.0ms
# Speed: 3.2ms preprocess, 157.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 160.5ms
# Speed: 3.4ms preprocess, 160.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 144.8ms
# Speed: 3.0ms preprocess, 144.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 144.2ms
# Speed: 3.3ms preprocess, 144.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 146.4ms
# Speed: 3.1ms preprocess, 146.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 152.3ms
# Speed: 3.1ms preprocess, 152.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 148.0ms
# Speed: 3.0ms preprocess, 148.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 156.3ms
# Speed: 5.3ms preprocess, 156.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 152.1ms
# Speed: 3.2ms preprocess, 152.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 147.7ms
# Speed: 3.0ms preprocess, 147.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 151.9ms
# Speed: 3.3ms preprocess, 151.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 146.2ms
# Speed: 3.4ms preprocess, 146.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 145.3ms
# Speed: 3.8ms preprocess, 145.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 156.6ms
# Speed: 4.6ms preprocess, 156.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 149.0ms
# Speed: 3.3ms preprocess, 149.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 151.6ms
# Speed: 4.4ms preprocess, 151.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 149.6ms
# Speed: 3.1ms preprocess, 149.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# ...
#
# 0: 384x640 14 persons, 173.1ms
# Speed: 4.2ms preprocess, 173.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 150.6ms
# Speed: 3.1ms preprocess, 150.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 157.5ms
# Speed: 3.0ms preprocess, 157.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 153.2ms
# Speed: 3.0ms preprocess, 153.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 147.2ms
# Speed: 3.0ms preprocess, 147.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 154.7ms
# Speed: 4.5ms preprocess, 154.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 168.1ms
# Speed: 3.3ms preprocess, 168.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 152.9ms
# Speed: 3.9ms preprocess, 152.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 150.7ms
# Speed: 3.3ms preprocess, 150.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 153.4ms
# Speed: 3.1ms preprocess, 153.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 1 sports ball, 148.4ms
# Speed: 3.4ms preprocess, 148.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 1 sports ball, 162.6ms
# Speed: 3.1ms preprocess, 162.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 152.7ms
# Speed: 3.3ms preprocess, 152.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 147.4ms
# Speed: 3.4ms preprocess, 147.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 155.9ms
# Speed: 3.4ms preprocess, 155.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 148.0ms
# Speed: 4.9ms preprocess, 148.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 150.2ms
# Speed: 3.3ms preprocess, 150.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 166.8ms
# Speed: 3.4ms preprocess, 166.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 152.5ms
# Speed: 3.1ms preprocess, 152.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 sports ball, 154.4ms
# Speed: 3.2ms preprocess, 154.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 157.4ms
# Speed: 3.2ms preprocess, 157.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 165.0ms
# Speed: 3.3ms preprocess, 165.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 150.3ms
# Speed: 3.2ms preprocess, 150.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 172.6ms
# Speed: 3.3ms preprocess, 172.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 150.3ms
# Speed: 8.0ms preprocess, 150.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 151.4ms
# Speed: 3.0ms preprocess, 151.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 157.2ms
# Speed: 3.4ms preprocess, 157.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 156.4ms
# Speed: 3.4ms preprocess, 156.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 158.1ms
# Speed: 4.1ms preprocess, 158.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 152.1ms
# Speed: 4.0ms preprocess, 152.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 155.0ms
# Speed: 3.5ms preprocess, 155.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 152.0ms
# Speed: 3.2ms preprocess, 152.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 157.2ms
# Speed: 3.3ms preprocess, 157.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 151.5ms
# Speed: 3.1ms preprocess, 151.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 165.6ms
# Speed: 3.4ms preprocess, 165.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 149.7ms
# Speed: 3.3ms preprocess, 149.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 sports ball, 149.8ms
# Speed: 3.5ms preprocess, 149.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 148.6ms
# Speed: 3.4ms preprocess, 148.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 152.9ms
# Speed: 3.3ms preprocess, 152.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 149.1ms
# Speed: 3.2ms preprocess, 149.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 1 sports ball, 165.0ms
# Speed: 4.9ms preprocess, 165.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 1 sports ball, 147.1ms
# Speed: 3.6ms preprocess, 147.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 151.8ms
# Speed: 3.7ms preprocess, 151.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 sports ball, 160.3ms
# Speed: 3.2ms preprocess, 160.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 151.5ms
# Speed: 3.1ms preprocess, 151.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 150.9ms
# Speed: 3.5ms preprocess, 150.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 171.0ms
# Speed: 3.5ms preprocess, 171.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 155.5ms
# Speed: 3.5ms preprocess, 155.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 1 sports ball, 153.0ms
# Speed: 3.2ms preprocess, 153.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 155.0ms
# Speed: 3.3ms preprocess, 155.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 178.3ms
# Speed: 7.1ms preprocess, 178.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 1 sports ball, 254.0ms
# Speed: 3.3ms preprocess, 254.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 1 sports ball, 244.8ms
# Speed: 3.1ms preprocess, 244.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 1 sports ball, 233.4ms
# Speed: 3.2ms preprocess, 233.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 sports ball, 230.7ms
# Speed: 3.3ms preprocess, 230.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 248.9ms
# Speed: 3.2ms preprocess, 248.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 221.9ms
# Speed: 3.3ms preprocess, 221.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 229.5ms
# Speed: 5.7ms preprocess, 229.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 220.3ms
# Speed: 5.1ms preprocess, 220.3ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 253.5ms
# Speed: 3.2ms preprocess, 253.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 229.8ms
# Speed: 3.3ms preprocess, 229.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 sports ball, 146.3ms
# Speed: 3.7ms preprocess, 146.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 145.2ms
# Speed: 3.1ms preprocess, 145.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 182.8ms
# Speed: 3.0ms preprocess, 182.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 163.5ms
# Speed: 3.3ms preprocess, 163.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 150.8ms
# Speed: 3.5ms preprocess, 150.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 161.6ms
# Speed: 3.4ms preprocess, 161.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 149.8ms
# Speed: 3.4ms preprocess, 149.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 146.5ms
# Speed: 3.3ms preprocess, 146.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 157.3ms
# Speed: 3.4ms preprocess, 157.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 149.8ms
# Speed: 3.1ms preprocess, 149.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 148.8ms
# Speed: 3.1ms preprocess, 148.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 150.8ms
# Speed: 3.2ms preprocess, 150.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 151.2ms
# Speed: 3.4ms preprocess, 151.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 145.0ms
# Speed: 3.0ms preprocess, 145.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 1 sports ball, 163.0ms
# Speed: 3.3ms preprocess, 163.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 1 sports ball, 152.2ms
# Speed: 3.0ms preprocess, 152.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 1 sports ball, 146.1ms
# Speed: 3.9ms preprocess, 146.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 144.5ms
# Speed: 3.2ms preprocess, 144.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 145.5ms
# Speed: 3.2ms preprocess, 145.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 153.0ms
# Speed: 3.3ms preprocess, 153.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 1 sports ball, 162.3ms
# Speed: 3.1ms preprocess, 162.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 1 sports ball, 150.1ms
# Speed: 5.3ms preprocess, 150.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 1 sports ball, 151.1ms
# Speed: 4.5ms preprocess, 151.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 1 sports ball, 151.5ms
# Speed: 2.8ms preprocess, 151.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 1 sports ball, 148.2ms
# Speed: 3.1ms preprocess, 148.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 1 sports ball, 152.3ms
# Speed: 3.2ms preprocess, 152.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 sports ball, 162.6ms
# Speed: 3.0ms preprocess, 162.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 sports ball, 143.8ms
# Speed: 3.4ms preprocess, 143.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 sports ball, 149.6ms
# Speed: 3.2ms preprocess, 149.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 sports ball, 147.2ms
# Speed: 3.5ms preprocess, 147.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 152.9ms
# Speed: 3.1ms preprocess, 152.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 sports ball, 148.9ms
# Speed: 3.9ms preprocess, 148.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 1 sports ball, 159.7ms
# Speed: 5.1ms preprocess, 159.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 1 sports ball, 150.6ms
# Speed: 3.2ms preprocess, 150.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 1 sports ball, 146.4ms
# Speed: 3.2ms preprocess, 146.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 1 sports ball, 151.6ms
# Speed: 3.1ms preprocess, 151.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 1 sports ball, 154.3ms
# Speed: 3.1ms preprocess, 154.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 1 sports ball, 167.2ms
# Speed: 3.3ms preprocess, 167.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 sports ball, 151.6ms
# Speed: 3.5ms preprocess, 151.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 1 sports ball, 149.3ms
# Speed: 3.4ms preprocess, 149.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 1 sports ball, 149.4ms
# Speed: 3.3ms preprocess, 149.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 1 sports ball, 155.4ms
# Speed: 3.4ms preprocess, 155.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 1 sports ball, 146.7ms
# Speed: 6.6ms preprocess, 146.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 1 sports ball, 165.0ms
# Speed: 3.4ms preprocess, 165.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 2 sports balls, 152.2ms
# Speed: 3.4ms preprocess, 152.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 145.3ms
# Speed: 3.0ms preprocess, 145.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 150.8ms
# Speed: 3.1ms preprocess, 150.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 151.5ms
# Speed: 3.1ms preprocess, 151.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 150.6ms
# Speed: 3.2ms preprocess, 150.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 1 sports ball, 161.9ms
# Speed: 3.1ms preprocess, 161.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 153.2ms
# Speed: 3.3ms preprocess, 153.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 144.4ms
# Speed: 3.3ms preprocess, 144.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 148.3ms
# Speed: 3.0ms preprocess, 148.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 149.1ms
# Speed: 3.1ms preprocess, 149.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 150.9ms
# Speed: 3.2ms preprocess, 150.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 235.5ms
# Speed: 3.3ms preprocess, 235.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 227.4ms
# Speed: 3.1ms preprocess, 227.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)

# %%
# SYSTEM DEPENDENCIES
# !apt update && apt install -y tesseract-ocr
# PYTHON DEPENDENCIES
# !pip install pytesseract opencv-python-headless ultralytics deep_sort_realtime
# Out:
# Hit:1 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:4 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Hit:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:7 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Hit:10 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [4,710 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,343 kB]
# Fetched 8,181 kB in 3s (2,900 kB/s)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 38 packages can be upgraded. Run 'apt list --upgradable' to see them.
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 38 not upgraded.
# Requirement already satisfied: pytesseract in /usr/local/lib/python3.11/dist-packages (0.3.13)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Requirement already satisfied: ultralytics in /usr/local/lib/python3.11/dist-packages (8.3.158)
# Collecting deep_sort_realtime
#   Downloading deep_sort_realtime-1.3.2-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.11/dist-packages (from pytesseract) (24.2)
# Requirement already satisfied: Pillow>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from pytesseract) (11.2.1)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.11/dist-packages (from opencv-python-headless) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.11.0.86)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (1.15.3)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.6.0+cu124)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.21.0+cu124)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.0.14)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2025.6.15)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (4.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Downloading deep_sort_realtime-1.3.2-py3-none-any.whl (8.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 56.0 MB/s eta 0:00:00
# Installing collected packages: deep_sort_realtime
# Successfully installed deep_sort_realtime-1.3.2

# %%
import cv2
from ultralytics import YOLO
from deep_sort_realtime.deepsort_tracker import DeepSort
import pytesseract
import numpy as np
from math import hypot

# Path to tesseract (for Colab)
pytesseract.pytesseract.tesseract_cmd = "/usr/bin/tesseract"

# Load model
model = YOLO("yolov8n.pt")  # You can use yolov8s.pt or yolov8m.pt for better results
tracker = DeepSort(max_age=30)

# Load video
video_path = "/content/test.mp4"  # ← Upload your video here
cap = cv2.VideoCapture(video_path)

# Output
output_path = "/content/output.avi"
out = cv2.VideoWriter(output_path,
                      cv2.VideoWriter_fourcc(*'XVID'),
                      30.0,
                      (int(cap.get(3)), int(cap.get(4))))

# Utility functions
def extract_jersey_number(frame, box):
    x1, y1, x2, y2 = map(int, box)
    jersey_crop = frame[y1:y2, x1:x2]
    if jersey_crop.size == 0:
        return ""
    resized = cv2.resize(jersey_crop, (100, 150))
    gray = cv2.cvtColor(resized, cv2.COLOR_BGR2GRAY)
    text = pytesseract.image_to_string(gray, config='--psm 6 digits')
    return ''.join(filter(str.isdigit, text.strip()))

def center(box):
    x1, y1, x2, y2 = box
    return ((x1 + x2) // 2, (y1 + y2) // 2)

def is_touch(player_box, ball_box, threshold=40):
    px, py = center(player_box)
    bx, by = center(ball_box)
    return hypot(px - bx, py - by) < threshold

# Tracking
target_jersey = "9"
target_id = None
touches = 0
last_touched = False

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    results = model(frame)[0]

    detections = []
    current_ball = None
    for box, cls, conf in zip(results.boxes.xyxy, results.boxes.cls, results.boxes.conf):
        x1, y1, x2, y2 = map(int, box[:4])
        if int(cls) == 0:
            detections.append(([x1, y1, x2 - x1, y2 - y1], conf.item(), 'player'))
        elif int(cls) == 32:
            current_ball = (x1, y1, x2, y2)

    tracks = tracker.update_tracks(detections, frame=frame)

    for track in tracks:
        if not track.is_confirmed():
            continue

        track_id = track.track_id
        l, t, r, b = track.to_ltrb()
        x1, y1, x2, y2 = int(l), int(t), int(r), int(b)

        # If player ID not assigned yet, check OCR
        if target_id is None:
            number = extract_jersey_number(frame, (x1, y1, x2, y2))
            if number == target_jersey:
                target_id = track_id
                print(f"🎯 Found jersey #{target_jersey} as track ID {track_id}")

        # If it's our target player
        if track_id == target_id:
            cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
            cv2.putText(frame, f"Player {target_jersey}", (x1, y1 - 10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)

            if current_ball:
                if is_touch((x1, y1, x2, y2), current_ball):
                    if not last_touched:
                        touches += 1
                        print(f"⚽️ Touch #{touches}")
                    last_touched = True
                else:
                    last_touched = False

    # Draw touches
    cv2.putText(frame, f"Touches: {touches}", (10, 30),
                cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 255), 2)

    out.write(frame)

cap.release()
out.release()
print("✅ Done! Output video saved to:", output_path)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-16-4241837652.py in <cell line: 0>()
#       1 import cv2
#       2 from ultralytics import YOLO
# ----> 3 from deep_sort_realtime.deepsort_tracker import DeepSort
#       4 import pytesseract
#       5 import numpy as np
#
# ModuleNotFoundError: No module named 'deep_sort_realtime'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
